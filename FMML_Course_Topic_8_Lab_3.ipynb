# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalamani226/Fmml_Project1-and-Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 05:36:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   117MB/s    in 0.6s
#
# 2024-04-01 05:36:32 (117 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 17  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36702   1311.3982v1  Correlations between anomalous activity patter...    cs
# 7760   1803.01834v1  The use of back-propagation and its variants t...    cs
# 11042   1312.0232v4  We consider a stochastic continuum armed bandi...  stat
# 27093  1702.03041v2  Deep neural networks (DNNs) trained on large-s...    cs
# 21566   1012.3880v1  We propose a novel application of the Simultan...  stat
# ...             ...                                                ...   ...
# 17010  1707.09067v1  In a controlled experiment of sequence-to-sequ...    cs
# 22832  1708.01529v1  We introduce a new algorithm for approximate i...  stat
# 5499    1205.1782v2  Approximate dynamic programming is a popular m...  stat
# 1157   1604.06154v1  Deep neural networks are state-of-the-art mode...    cs
# 22817  1707.06626v2  We propose a simple algorithm to train stochas...  stat
#
#                                                    title  year  \
# 36702  Inferring Multilateral Relations from Dynamic ...  2013
# 7760   Conducting Credit Assignment by Aligning Local...  2018
# 11042  Stochastic continuum armed bandit problem of f...  2013
# 27093  Reconstruction-Based Disentanglement for Pose-...  2017
# 21566  Ultra-high Dimensional Multiple Output Learnin...  2010
# ...                                                  ...   ...
# 17010   Adapting Sequence Models for Sentence Correction  2017
# 22832  Learning Model Reparametrizations: Implicit Va...  2017
# 5499   Approximate Dynamic Programming By Minimizing ...  2012
# 1157   Deep Adaptive Network: An Efficient Deep Neura...  2016
# 22817  Learning to Draw Samples with Amortized Stein ...  2017
#
#                                                 keywords
# 36702  [correlations, anomalous, pertinent, informati...
# 7760   [propagation, problematic, exploding, gradient...
# 11042  [stochastic, continuum, functions, rightarrow,...
# 27093  [impressive, improvements, recognition, persis...
# 21566  [application, simultaneous, orthogonal, proced...
# ...                                                  ...
# 17010  [controlled, experiment, approaches, correctio...
# 22832  [introduce, algorithm, approximate, inference,...
# 5499   [approximate, programming, processes, describe...
# 1157   [understanding, implementing, challenging, ban...
# 22817  [algorithm, stochastic, distributions, probabi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36702    [correlations, anomalous, pertinent, informati...
# 7760     [propagation, problematic, exploding, gradient...
# 11042    [stochastic, continuum, functions, rightarrow,...
# 27093    [impressive, improvements, recognition, persis...
# 21566    [application, simultaneous, orthogonal, proced...
#                                ...
# 40528    [factorization, processing, informatics, appro...
# 10424    [framework, minimizing, concordant, computable...
# 20333    [extension, neighbourhood, integrates, complem...
# 40838    [recursive, algorithm, variables, identificati...
# 37355    [dissertation, motivated, globalist, governmen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8829 words.
# Out of those 4542 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2758dff-3800-4293-b1a7-2094a7a7c04c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2758dff-3800-4293-b1a7-2094a7a7c04c")) {                    Plotly.newPlot(                        "c2758dff-3800-4293-b1a7-2094a7a7c04c",                        [{"x":["correlations","simultaneously","information","introduce","community","inferring","recommend","deviation","interaction","significant","considerable","nonparametric","relationships","involving","anomalous","interactions","exhibited","unexplored","structure","capabilities","correspond","international","deviations","characterize","explicitly","relations","pertinent","processes","underlying","relationship","sensitive","nonlinearities","biologically","effectively","propagation","problematic","exploding","gradients","representations","initialization","initializations","assignment","plausible","experiments","successfully","strategies","furthermore","representation","nonlinear","conducting","performance","alignment","activation","procedure","outperforming","alternative","vanishing","variation","algorithm","sensitivity","algorithms","difficult","architecture","functions","including","modifications","literature","intrinsically","randomized","dimensions","parameters","continuum","probability","efficient","stochastic","considered","beforehand","polynomial","rightarrow","demanding","reconstructions","reconstruction","diversity","consistently","controlled","relatively","variations","embedding","locations","challenge","persistent","especially","contribution","improvements","disentangle","invariant","combinations","discrimination","preserving","requiring","extensive","outperforms","impressive","recognition","disentanglement","separately","demonstrated","simulation","iterations","retaining","orthogonal","guaranteed","relatedness","computationally","empirical","regression","variables","knowledge","performing","theoretical","thousands","association","criterion","simultaneous","asymptotically","introduced","application","dimensional","selection","irrelevant","efficiently","determine","screening","manageable","different","comparison","employment","education","observational","answering","justification","widespread","framework","healthcare","questions","approaches","adaptation","counterfactual","importance","algorithmic","inference","medication","significantly","accumulation","challenging","worthwhile","challenges","rewarding","attention","generated","argumentation","attracted","motivation","increasing","manipulated","carefully","manipulate","realizing","manipulating","transparent","diminished","therefore","localizing","applications","suggested","anatomical","individually","landmarks","according","estimation","consistent","estimating","consequently","important","promising","extracted","automatic","automating","categorized","characteristics","detection","treatment","effectiveness","identifying","illustrate","partially","hyperparameters","addresses","posteriori","distribution"],"y":[22,107,671,343,80,22,6,19,89,230,36,19,69,34,3,62,6,5,349,53,27,18,9,44,71,85,7,95,117,72,58,2,15,112,74,11,3,37,199,24,3,40,28,574,98,100,171,343,59,8,897,56,33,143,28,100,11,56,845,35,585,135,234,208,241,23,122,5,17,46,283,2,180,427,127,118,6,79,2,9,13,92,42,35,25,43,69,96,42,155,11,127,93,109,6,58,49,13,48,46,166,282,18,400,2,29,99,83,19,11,20,22,9,111,164,110,124,325,74,155,25,35,57,32,6,113,250,178,169,10,153,62,8,3,749,132,4,9,8,53,12,18,545,4,57,419,65,2,95,40,214,1,276,6,280,2,124,3,162,178,17,24,20,95,4,25,12,3,12,9,1,122,10,448,29,9,14,14,107,218,83,72,31,335,115,119,222,9,6,88,349,32,196,69,67,48,13,61,12,250],"type":"bar"},{"x":["correlations","simultaneously","information","introduce","community","inf ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4542,), (4542, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Explainable</span> <span style=''>Entity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recommendations</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>Knowledge</span> <span style=''>Graphs</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Explainable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>task</span> <span style=''>Many</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>which</span> <span style=''>generate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>content</span> <span style=''>and</span> <span style=''>reviews</span> <span style=''>written</span> <span style=''>for</span> <span style=''>items</span> <span style=''>When</span> <span style=''>review</span> <span style=''>text</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>unavailable</span> <span style='background-color:rgba(0, 255, 0, 0.3378378378378379);'>generating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>is</span> <span style=''>still</span> <span style=''>a</span> <span style=''>hard</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3557692307692307);'>illustrate</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>in</span> <span style=''>such</span> <span style=''>a</span> <span style=''>scenario</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraging</span> <span style=''>external</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>knowledge</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>knowledge</span> <span style=''>graphs</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>jointly</span> <span style=''>ranks</span> <span style=''>items</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>knowledge</span> <span style=''>graph</span> <span style=''>entities</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Personalized</span> <span style=''>PageRank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendations</span> <span style=''>together</span> <span style=''>with</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Spatio</span> <span style=''>Temporal</span> <span style=''>Point</span> <span style=''>Process</span> <span style=''>Models</span> <br/><br/><span style=''>Spatio</span> <span style=''>temporal</span> <span style=''>point</span> <span style=''>process</span> <span style=''>models</span> <span style=''>play</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>systems</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disciplines</span> <span style=''>Yet</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>remains</span> <span style=''>computa</span> <span style=''>tionally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>both</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>required</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>function</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>typical</span> <span style=''>of</span> <span style=''>(spatially)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discretised</span> <span style=''>log</span> <span style=''>Gaussian</span> <span style=''>Cox</span> <span style=''>process</span> <span style=''>models</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>message</span> <span style=''>passing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>scale</span> <span style=''>well</span> <span style=''>with</span> <span style=''>the</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style=''>the</span> <span style=''>length</span> <span style=''>of</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>horizon</span> <span style=''>with</span> <span style=''>moderate</span> <span style=''>loss</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style=''>accuracy</span> <span style=''>They</span> <span style=''>hence</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>and</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>both</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.7185185185185186);'>Nonparametric</span> <span style=''>Bayesian</span> <span style=''>Logic</span> <br/><br/><span style=''>The</span> <span style=''>Bayesian</span> <span style=''>Logic</span> <span style=''>(BLOG)</span> <span style=''>language</span> <span style=''>was</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>defining</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>models</span> <span style=''>over</span> <span style=''>worlds</span> <span style=''>with</span> <span style=''>unknown</span> <span style=''>numbers</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>It</span> <span style=''>handles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>AI</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>association</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>extends</span> <span style=''>BLOG</span> <span style=''>by</span> <span style=''>adopting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>over</span> <span style=''>function</span> <span style=''>spaces</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>nonparametrics</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>syntax</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7826086956521738);'>reasoning</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>manner</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exchangeability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>unknown</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5368421052631578);'>attributes</span> <span style=''>are</span> <span style=''>cast</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.4722222222222223);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>which</span> <span style=''>resolve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>in</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>varying</span> <span style=''>numbers</span> <span style=''>of</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intermediate</span> <span style=''>layers</span> <span style=''>using</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>probes</span> <br/><br/><span style=''>Neural</span> <span style=''>network</span> <span style=''>models</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reputation</span> <span style=''>for</span> <span style=''>being</span> <span style=''>black</span> <span style=''>boxes</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>better</span> <span style=''>the</span> <span style=''>roles</span> <span style=''>and</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intermediate</span> <span style=''>layers</span> <span style=''>This</span> <span style=''>has</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequences</span> <span style=''>on</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style=''>such</span> <span style=''>models</span> <span style=''>and</span> <span style=''>it</span> <span style=''>enables</span> <span style=''>the</span> <span style=''>expert</span> <span style=''>to</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>justify</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heuristics</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>auxiliary</span> <span style=''>heads</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inception</span> <span style=''>model)</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>uses</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>probes</span> <span style=''>where</span> <span style=''>a</span> <span style=''>probe</span> <span style=''>can</span> <span style=''>only</span> <span style=''>use</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>units</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intermediate</span> <span style=''>layer</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminating</span> <span style=''>features</span> <span style=''>Moreover</span> <span style=''>these</span> <span style=''>probes</span> <span style=''>cannot</span> <span style=''>affect</span> <span style=''>the</span> <span style=''>training</span> <span style=''>phase</span> <span style=''>of</span> <span style=''>a</span> <span style=''>model</span> <span style=''>and</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>added</span> <span style=''>after</span> <span style=''>training</span> <span style=''>They</span> <span style=''>allow</span> <span style=''>the</span> <span style=''>user</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualize</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>at</span> <span style=''>multiple</span> <span style=''>steps</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.1001788908765653)
# 	information (0.24007155635062613)
# 	architecture (0.08372093023255814)
# 	automatic (0.07942754919499105)
# 	segmentation (0.07334525939177101)
# 	experimental (0.14561717352415027)
# 	detection (0.12486583184257603)
# 	convolutional (0.12808586762075133)
# 	different (0.2679785330948122)
# 	recognition (0.14311270125223613)
#
# Some Statistics words are:
# 	stochastic (0.13266832917705737)
# 	estimation (0.17007481296758103)
# 	distribution (0.18304239401496258)
# 	variables (0.13865336658354116)
# 	algorithm (0.40399002493765584)
# 	statistical (0.16159600997506235)
# 	theoretical (0.15860349127182044)
# 	dimensional (0.17955112219451372)
# 	inference (0.19600997506234413)
# 	regression (0.17356608478802993)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3b9a3426-0e5c-4cc7-8129-9bce16ed59e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b9a3426-0e5c-4cc7-8129-9bce16ed59e1")) {                    Plotly.newPlot(                        "3b9a3426-0e5c-4cc7-8129-9bce16ed59e1",                        [{"x":["correlations","simultaneously","information","introduce","community","inferring","recommend","deviation","interaction","significant","considerable","nonparametric","relationships","involving","anomalous","interactions","exhibited","unexplored","structure","capabilities","correspond","international","deviations","characterize","explicitly","relations","pertinent","processes","underlying","relationship","sensitive","nonlinearities","biologically","effectively","propagation","problematic","exploding","gradients","representations","initialization","initializations","assignment","plausible","experiments","successfully","strategies","furthermore","representation","nonlinear","conducting","performance","alignment","activation","procedure","outperforming","alternative","vanishing","variation","algorithm","sensitivity","algorithms","difficult","architecture","functions","including","modifications","literature","intrinsically","randomized","dimensions","parameters","continuum","probability","efficient","stochastic","considered","beforehand","polynomial","rightarrow","demanding","reconstructions","reconstruction","diversity","consistently","controlled","relatively","variations","embedding","locations","challenge","persistent","especially","contribution","improvements","disentangle","invariant","combinations","discrimination","preserving","requiring","extensive","outperforms","impressive","recognition","disentanglement","separately","demonstrated","simulation","iterations","retaining","orthogonal","guaranteed","relatedness","computationally","empirical","regression","variables","knowledge","performing","theoretical","thousands","association","criterion","simultaneous","asymptotically","introduced","application","dimensional","selection","irrelevant","efficiently","determine","screening","manageable","different","comparison","employment","education","observational","answering","justification","widespread","framework","healthcare","questions","approaches","adaptation","counterfactual","importance","algorithmic","inference","medication","significantly","accumulation","challenging","worthwhile","challenges","rewarding","attention","generated","argumentation","attracted","motivation","increasing","manipulated","carefully","manipulate","realizing","manipulating","transparent","diminished","therefore","localizing","applications","suggested","anatomical","individually","landmarks","according","estimation","consistent","estimating","consequently","important","promising","extracted","automatic","automating","categorized","characteristics","detection","treatment","effectiveness","identifying","illustrate","partially","hyperparameters","addresses","posteriori","distribution","unobserved","separation","investigated","conducted","collapsed","synthetic","estimator","posterior","appropriate","approximate","represented","simulations","distributed","informative","formulated","dictionary","component","recovering","bernoulli","fundamental","observations","typically","operations","approximately","sufficient","theoretically","population","prohibitively","quadratic","requirements","following","contemporary","computation","conditions","estimated","computing","computational","detecting","covariance","precisely","discretization","constraints","splitting","intelligent","deployment","generalized","optimization","surveillance","emphexactly","coefficient","laplacian","interpretation","analogous","solutions", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	autocorrelation
# 	determinant
# 	dispersion
# 	recombines
# 	prespecified
# 	depression
# 	precludes
# 	katehakis
# 	activates
# 	gaussianity
# 	procrustes
# 	heteroskedastic
# 	archetypes
# 	imaginary
# 	supercomputers
# 	variationally
# 	nontrivially
# 	mitigates
# 	neuroscientists
# 	cancellation
# Some words which never appear in Statistics papers:
# 	disentangle
# 	rewarding
# 	argumentation
# 	localizing
# 	categorized
# 	emphexactly
# 	terminology
# 	terminological
# 	antagonistic
# 	workforce
# 	extrinsic
# 	paragraph
# 	discourse
# 	watershed
# 	september
# 	fertilization
# 	commonsense
# 	inhibition
# 	nonmonotonic
# 	abductive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077680659854734e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
